# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

origin_path = "/kaggle/working"
repo_path = "/kaggle/working/american_options"

# %%
# %%capture
# !rm -rf /kaggle/working/
# !git clone https://github.com/konmue/american_options.git

# %%
os.chdir(repo_path)

# %%
# %%capture
# !python setup.py install

# %%
import pandas as pd

from deep_ao.algorithms.deep_lsm.main import main

# %%
results = main([5])
# Out:
# training model for d = 5, s0 = 90
# Training network 8
# Training: 0it [00:00, ?it/s]
# Training network 7
# Training: 0it [00:00, ?it/s]
# Training network 6
# Training: 0it [00:00, ?it/s]
# Training network 5
# Training: 0it [00:00, ?it/s]
# Training network 4
# Training: 0it [00:00, ?it/s]
# Training network 3
# Training: 0it [00:00, ?it/s]
# Training network 2
# Training: 0it [00:00, ?it/s]
# Training network 1
# Training: 0it [00:00, ?it/s]
# 100%|██████████| 9/9 [01:49<00:00, 12.20s/it]
# (16.61851631259482, 16.60419657751166, 16.65626575839321, 16.66315731683661)
# training model for d = 5, s0 = 100
# Training network 8
# Training: 0it [00:00, ?it/s]
# Training network 7
# Training: 0it [00:00, ?it/s]
# Training network 6
# Training: 0it [00:00, ?it/s]
# Training network 5
# Training: 0it [00:00, ?it/s]
# Training network 4
# Training: 0it [00:00, ?it/s]
# Training network 3
# Training: 0it [00:00, ?it/s]
# Training network 2
# Training: 0it [00:00, ?it/s]
# Training network 1
# Training: 0it [00:00, ?it/s]
# 100%|██████████| 9/9 [01:45<00:00, 11.76s/it]
# (26.103882130100544, 26.086880589527347, 26.182582772354067, 26.196742986791037)
# training model for d = 5, s0 = 110
# Training network 8
# Training: 0it [00:00, ?it/s]
# Training network 7
# Training: 0it [00:00, ?it/s]
# Training network 6
# Training: 0it [00:00, ?it/s]
# Training network 5
# Training: 0it [00:00, ?it/s]
# Training network 4
# Training: 0it [00:00, ?it/s]
# Training network 3
# Training: 0it [00:00, ?it/s]
# Training network 2
# Training: 0it [00:00, ?it/s]
# Training network 1
# Training: 0it [00:00, ?it/s]
# 100%|██████████| 9/9 [01:44<00:00, 11.65s/it]
# (36.68558362828489, 36.6660699107991, 36.79322408847924, 36.80705127528035)

# %%
results
# Out:
#    d  S_0          L   ci_lower          U   ci_upper
# 0  5   90  16.618516  16.604197  16.656266  16.663157
# 1  5  100  26.103882  26.086881  26.182583  26.196743
# 2  5  110  36.685584  36.666070  36.793224  36.807051

# %%
print(results.to_latex(float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  d &  S\_0 &     L &  ci\_lower &     U &  ci\_upper \\
# \midrule
# 0 &  5 &   90 & 16.62 &     16.60 & 16.66 &     16.66 \\
# 1 &  5 &  100 & 26.10 &     26.09 & 26.18 &     26.20 \\
# 2 &  5 &  110 & 36.69 &     36.67 & 36.79 &     36.81 \\
# \bottomrule
# \end{tabular}
